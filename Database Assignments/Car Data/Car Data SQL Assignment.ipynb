# %% [raw]
# 1 . Take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
# 2 . Create a database called as cardataset
# 3 . Create a table called as car with a column name given in dataset description
# 4 . Dump all the data into car table
# 5 . Try to check weather all the data is aviable inside your table or not
# 6 . Tryto group all the data with COL1 AND count occurences of each and every record based on col1 value
# 7 . Try to filter a record where col 3 value will be 4 .
# 8.  Try to update a col 3 value with 8 whereever you have value equal to 2
# 9 . Try to delete table
# 10 .Try to delete database

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost',user = 'root' ,passwd = "Tubzi@123" )

# %%
mydb #pointer

# %%
cursor = mydb.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testdb',),
#  ('testdb1',),
#  ('testdb3',)]

# %%
#create database
cursor.execute('create database car_db')

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('car_db',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testdb',),
#  ('testdb1',),
#  ('testdb3',)]

# %%
cursor.execute('use car_db')

# %%
#create table
query='create table car_db.car(buying VARCHAR(20) ,maint VARCHAR(20),doors VARCHAR(10) ,persons VARCHAR(20) , lug_boot VARCHAR(20),safety VARCHAR(20), class VARCHAR(20))'
cursor.execute(query)

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('car',)]

# %%
#Dump car data to table
import csv
with open('car.data','r') as f:
    car_data=csv.reader(f,delimiter=',')
    for i in car_data:
        file=tuple([f'{row}' for row in i])
        print(f'insert into car_db.car values{file}')
        cursor. execute(f'insert into car_db.car values{file}')
mydb.commit()
# Out:
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc')
# insert into car_db.car values('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc')
# ...

# %%
#check data
cursor.execute('select * from car_db.car')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
#group col1 and count values
query = "SELECT buying, count(*) FROM car_db.car GROUP BY buying"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
#filter a record where col 3 value will be 4 
query="select * from car_db.car where doors=4"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
#update a col 3 value with 8 wherever you have value equal to 2
cursor.execute('select * from car_db.car where doors=8')
cursor.fetchall()

#no such row is present
# Out:
# []

# %%
cursor.execute("SELECT doors, count(*) FROM car_db.car GROUP BY doors")
cursor.fetchall()
# Out:
# [('2', 432), ('3', 432), ('4', 432), ('5more', 432)]

# %%
cursor.execute("update car_db.car set doors='5' where doors='5more' ")
mydb.commit()

# %%
cursor.execute("SELECT doors, count(*) FROM car_db.car GROUP BY doors")
cursor.fetchall()
# Out:
# [('2', 432), ('3', 432), ('4', 432), ('5', 432)]

# %%
#delete table
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('car_db',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testdb',),
#  ('testdb1',),
#  ('testdb3',)]

# %%
cursor.execute('use testdb')
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('glassdata',), ('table1',)]

# %%
cursor.execute('drop table testdb.table1')
mydb.commit()

# %%
cursor.execute('use testdb')
cursor.execute('show tables')
cursor.fetchall()

#table1 is deleted
# Out:
# [('glassdata',)]

# %%
#Delete Database
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('car_db',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testdb',),
#  ('testdb1',),
#  ('testdb3',)]

# %%
cursor.execute('drop database testdb3')
mydb.commit()

# %%
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('car_db',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testdb',),
#  ('testdb1',)]
